# %% [markdown]
# Used this code from the pandas intro to mount my google drive and open the csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# import csv and pandas, set the dataframe

# %%
import csv
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/DATA/olympic_medals.csv")

# %% [markdown]
# 2 A) Find the size of the data frame. How many rows, how many columns?

# %%
df.shape
# Out:
# (2394, 8)

# %% [markdown]
# 2 B) Use the appropriate function to report the data types for all columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2394 entries, 0 to 2393
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       2394 non-null   object
#  1   Event        2394 non-null   object
#  2   Location     2394 non-null   object
#  3   Year         2394 non-null   int64
#  4   Medal        2394 non-null   object
#  5   Name         2164 non-null   object
#  6   Nationality  2394 non-null   object
#  7   Result       2394 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 149.8+ KB

# %% [markdown]
# 2 C) Find how many unique locations olympics were held at.

# %%
df['Location'].unique()
# Out:
# array(['Rio', 'Beijing', 'Sydney', 'Barcelona', 'Los Angeles', 'Montreal',
#        'Mexico', 'Rome', 'Helsinki', 'Berlin', 'Amsterdam', 'Antwerp',
#        'London', 'Athens', 'Atlanta', 'Moscow', 'Munich', 'Tokyo',
#        'Melbourne / Stockholm', 'Paris', 'Stockholm', 'St Louis', 'Seoul'],
#       dtype=object)

# %% [markdown]
# 2 D) Find how many medals the USA team won in total.

# %%
df[df['Nationality']=='USA'].groupby('Nationality').count()
# Out:
#              Gender  Event  Location  Year  Medal  Name  Result
# Nationality
# USA             638    638       638   638    638   577     638

# %% [markdown]
# 2 E) Find the total number of medals for each Nationality. (Hint: please search for groupby() function with count)

# %%
df.groupby(['Nationality','Medal']).count()
# Out:
#                    Gender  Event  Location  Year  Name  Result
# Nationality Medal
# ALG         B           2      2         2     2     2       2
#             G           4      4         4     4     4       4
#             S           3      3         3     3     3       3
# ARG         G           2      2         2     2     2       2
#             S           2      2         2     2     2       2
# ...                   ...    ...       ...   ...   ...     ...
# USA         S         206    206       206   206   196     206
# VEN         B           1      1         1     1     1       1
#             S           1      1         1     1     1       1
# YUG         S           1      1         1     1     1       1
# ZAM         S           1      1         1     1     1       1
#
# [218 rows x 6 columns]

# %% [markdown]
# Loading cause of death CSV

# %%
import csv
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/DATA/causes_of_death.csv")

# %% [markdown]
# 3 A) Find the size of the data frame. How many rows, how many columns?

# %%
df.shape
# Out:
# (4115, 11)

# %% [markdown]
# 3 B) What is the average death count across the country?

# %%
df['Deaths'].mean()
# Out:
# 10914.44957472661

# %% [markdown]
# 3 C) What is the total death count for each state. (Hint: please search for groupby() function with sum)

# %%
df.groupby(['State']).sum(['Deaths'])
# Out:
#                       State Code   Deaths   Population  Crude Rate
# State
# Alabama                       81   860780   83746349.0    155909.1
# Alaska                       164    63334   12140925.0    178260.3
# Arizona                      368   838094  109191391.0    163792.9
# Arkansas                     405   522914   50938331.0    164654.0
# California                   564  4307061  657732064.0    147922.3
# Colorado                     704   561283   87470624.0    150571.2
# Connecticut                  729   531290   63270366.0    130589.1
# 3 E) What is the total death count for males and females in each state. (Hint: groupby() function with sum, but you
# will have two attributes/columns for the groupby() )

# %%
df.groupby(['State', 'Gender']).sum()
# Out:
#                       State Code  Deaths  Population  Crude Rate
# State         Gender
# Alabama       Female          40  430133  43148507.0     69294.4
#               Male            41  430647  40597842.0     86614.7
# Alaska        Female          80   27199   5761611.0     77863.9
#               Male            84   36135   6379314.0    100396.4
# Arizona       Female         180  396028  54846072.0     73199.1
# ...                          ...     ...         ...         ...
# West Virginia Male          1674  192560  16087802.0     76930.9
# Wisconsin     Female        2420  436397  50807788.0     83793.6
#               Male          2420  421232  49954108.0    107111.4
# Wyoming       Female        1792   37153   4696239.0     66382.2
#               Male          1960   40233   4872826.0     68545.2
#
# [102 rows x 4 columns]

# %% [markdown]
# 3 F) Drop your rows which have NA in it. Then verify it by using head() to show they are removed. (Hint: dropna())

# %%
df.dropna()
df.head()
# Out:
#      State  State Code Ten-Year Age Groups  ... Population Crude Rate     Ratio
# 0  Alabama           1            < 1 year  ...     3579.0        NaN  0.003912
# 1  Alabama           1            < 1 year  ...     7443.0      322.5  0.003225
# 2  Alabama           1            < 1 year  ...   169339.0     1236.0  0.012360
# 3  Alabama           1            < 1 year  ...   347921.0      616.2  0.006162
# 4  Alabama           1            < 1 year  ...     7366.0      448.0  0.004480
#
# [5 rows x 12 columns]

# %% [markdown]
# 3 G) Create a column called ratio and assign the ratio of death counts to population to fill its values. Then verify it
# by using head().

# %%
df['Ratio'] = df['Deaths']/(df['Population'])
df.head()
# Out:
#      State  State Code Ten-Year Age Groups  ... Population Crude Rate     Ratio
# 0  Alabama           1            < 1 year  ...     3579.0        NaN  0.003912
# 1  Alabama           1            < 1 year  ...     7443.0      322.5  0.003225
# 2  Alabama           1            < 1 year  ...   169339.0     1236.0  0.012360
# 3  Alabama           1            < 1 year  ...   347921.0      616.2  0.006162
# 4  Alabama           1            < 1 year  ...     7366.0      448.0  0.004480
#
# [5 rows x 12 columns]

# %% [markdown]
# 3 H) Select only rows where Ten-Year Age Groups Code is equal to 1. Notice that this column has string data type.

# %%
df2=df[df['Ten-Year Age Groups Code']=='1']
df2
# Out:
#         State  State Code Ten-Year Age Groups  ... Deaths Population Crude Rate
# 0     Alabama           1            < 1 year  ...     14     3579.0        NaN
# 1     Alabama           1            < 1 year  ...     24     7443.0      322.5
# 2     Alabama           1            < 1 year  ...   2093   169339.0     1236.0
# 3     Alabama           1            < 1 year  ...   2144   347921.0      616.2
# 4     Alabama           1            < 1 year  ...     33     7366.0      448.0
# ...       ...         ...                 ...  ...    ...        ...        ...
# 4048  Wyoming          56            < 1 year  ...     19     3260.0        NaN
# 4049  Wyoming          56            < 1 year  ...    327    57791.0      565.8
# 4050  Wyoming          56            < 1 year  ...     41     3366.0     1218.1
# 4051  Wyoming          56            < 1 year  ...     11     1572.0        NaN
# 4052  Wyoming          56            < 1 year  ...    415    60874.0      681.7
#
# [354 rows x 11 columns]

# %% [markdown]
# 3 I) Use the selected rows above (you can either assign to another variable or keep using dot(.) operator) to chain
# with other functions (groupby, sum, sort_values) to view your data sorted from the highest Crude rate to
# the smallest. This will show the infant mortality rate for all states.

# %%
df2.groupby('State').sum().sort_values('Crude Rate', ascending=False)
# Out:
#                       State Code  Deaths  Population  Crude Rate
# State
# Mississippi                  224    7441    735284.0      7682.7
# Oklahoma                     320    7324    922219.0      6723.5
# North Carolina               296   17430   2160788.0      6442.4
# Wisconsin                    440    7909   1239313.0      6417.3
# Michigan                     208   16513   2184807.0      6219.8
# Kansas                       160    4885    709234.0      5850.7
# Arizona                       32   10153   1571511.0      5602.3
# Minnesota                    216    6477   1239873.0      5526.6
# South Dakota                 276    1440    201855.0      5499.9
# North Dakota                 228    1059    157084.0      5489.9
# Alaska                        16    1176    189233.0      5437.9
# Georgia                      104   19088   2388308.0      5294.5
# Illinois                     136   22039   3010235.0      5270.0
# Nebraska                     248    2765    459680.0      5216.3
# Arkansas                      35    5469    681641.0      5194.1
# Louisiana                    176   10362   1133812.0      5116.3
# Tennessee                    282   11741   1414671.0      5066.8
# Indiana                      108   11673   1522088.0      4969.7
# Alabama                        7    9828   1072918.0      4965.6
# Ohio                         273   20080   2571956.0      4902.0
# Colorado                      64    6950   1189964.0      4869.7
# Virginia                     408   12787   1804460.0      4848.7
# Missouri                     203    9888   1355762.0      4679.3
# Washington                   424    7672   1530292.0      4672.3
# Nevada                       256    3708    630443.0      4657.3
# Pennsylvania                 252   18281   2559629.0      4616.0
# South Carolina               315    8436   1034323.0      4588.1
# Florida                       96   26770   3808185.0      4413.4
# Maryland                     192    9892   1312757.0      4321.3
# Oregon                       328    4403    824379.0      4301.5
# Hawaii                        90    2039    317993.0      4280.3
# Kentucky                     126    6912    990831.0      4257.7
# Utah                         392    4657    891407.0      4238.0
# Texas                        384   42088   6769548.0      4176.1
# Delaware                      60    1682    196455.0      4154.5
# District of Columbia          44    1541    134706.0      4151.7
# California                    48   46975   9163634.0      4074.3
# West Virginia                216    2795    369035.0      3880.1
# Rhode Island                 264    1324    206609.0      3826.1
# Connecticut                   54    4067    706547.0      3822.7
# New Mexico                   280    2980    498539.0      3809.9
# Iowa                         114    3657    691738.0      3787.3
# New York                     288   24369   4332295.0      3709.1
# New Jersey                   204   10556   1928325.0      3642.1
# Montana                      180    1310    209748.0      3117.8
# Massachusetts                150    6407   1339219.0      3116.4
# Maine                        138    1410    238961.0      2571.2
# Wyoming                      280     813    126863.0      2465.6
# New Hampshire                198    1173    246082.0      2407.5
# Idaho                        128    2415    403288.0      2216.2
# Vermont                      100     542    106419.0      1013.1
